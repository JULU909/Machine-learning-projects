# %%
# !pip install xgboost
from os import environ, path
import pandas as pd
import xgboost

from sklearn.model_selection import train_test_split, KFold, GridSearchCV
from sklearn.metrics import mean_squared_error, mean_absolute_error
# Out:
# ...
#      --------------------------------------- 70.9/70.9 MB 16.8 MB/s eta 0:00:00
# ...

# %%
cleaned_data = pd.read_csv(path.join('C:/Users/julu9/Codes/Machine-learning-projects/DeliveryPredictionModel/data/', 'cleaned_data.csv'), index_col=0).reset_index(drop=True)
cleaned_data.drop(columns=['date','created_at','actual_delivery_time','date.1'])
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']

cleaned_data = cleaned_data.select_dtypes(include=numerics)
cleaned_data
# Out:
#         total_items  subtotal  num_distinct_items  min_item_price  \
# 0                 4      3441                   4             557
# 1                 1      1900                   1            1400
# 2                 1      1900                   1            1900
# 3                 6      6900                   5             600
# 4                 3      3900                   3            1100
# ...             ...       ...                 ...             ...
# 197423            3      1389                   3             345
# 197424            6      3010                   4             405
# 197425            5      1836                   3             300
# 197426            1      1175                   1             535
# 197427            4      2605                   4             425
#
#         max_item_price  total_onshift_dashers  total_busy_dashers  \
# 0                 1239                   33.0                14.0
# ...

# %%
y = cleaned_data.reindex(columns=['actual_time_taken'])

x = cleaned_data.drop(columns=['actual_time_taken'])

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, shuffle=True, random_state=0)

# %%
model = xgboost.XGBRegressor()
history = model.fit(
    x_train, y_train,
    eval_set=[(x_test, y_test)],
    eval_metric=['rmse', 'mae'], 
    early_stopping_rounds=10)
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26996\2992453821.py in <module>
#       1 model = xgboost.XGBRegressor()
# ----> 2 history = model.fit(
#       3     x_train, y_train,
#       4     eval_set=[(x_test, y_test)],
#       5     eval_metric=['rmse', 'mae'],
#
# c:\Users\julu9\anaconda3\lib\site-packages\xgboost\core.py in inner_f(*args, **kwargs)
#     618             for k, arg in zip(sig.parameters, args):
#     619                 kwargs[k] = arg
# --> 620             return func(**kwargs)
#     621
#     622         return inner_f
#
# c:\Users\julu9\anaconda3\lib\site-packages\xgboost\sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
# ...

# %%
cleaned_data.dropna()
# Out:
#         total_items  subtotal  num_distinct_items  min_item_price  \
# 0                 4      3441                   4             557
# 1                 1      1900                   1            1400
# 8                 4      4771                   3             820
# 14                1      1525                   1            1525
# 15                2      3620                   2            1425
# ...             ...       ...                 ...             ...
# 197423            3      1389                   3             345
# 197424            6      3010                   4             405
# 197425            5      1836                   3             300
# 197426            1      1175                   1             535
# 197427            4      2605                   4             425
#
#         max_item_price  total_onshift_dashers  total_busy_dashers  \
# 0                 1239                   33.0                14.0
# ...

# %%
import numpy as np
x_train = np.nan_to_num(x_train)
