# %%
import yfinance as yf
import pandas as pd



ticker = yf.Ticker('AAPL')
data = ticker.history(period="24mo", interval="1d")
print(data.head())
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2021-06-10 00:00:00-04:00  125.548748  126.705202  124.481263  124.649292
# 2021-06-11 00:00:00-04:00  125.064422  125.963885  124.639402  125.874924
# 2021-06-14 00:00:00-04:00  126.339503  129.027992  125.598190  128.968689
# 2021-06-15 00:00:00-04:00  128.434941  129.087300  127.891308  128.138412
# 2021-06-16 00:00:00-04:00  128.859940  129.373921  126.972074  128.642487
#
#                              Volume  Dividends  Stock Splits
# Date
# 2021-06-10 00:00:00-04:00  71186400        0.0           0.0
# 2021-06-11 00:00:00-04:00  53522400        0.0           0.0
# 2021-06-14 00:00:00-04:00  96906500        0.0           0.0
# 2021-06-15 00:00:00-04:00  62746300        0.0           0.0
# 2021-06-16 00:00:00-04:00  91815000        0.0           0.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data['Daily Return'] = data['Close'].pct_change()

# %%
plt.figure(figsize=(14,7))
plt.plot(data['Close'])
plt.title('Close Price History')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.title('Heatmap of Correlation Between Stocks')
plt.show()
