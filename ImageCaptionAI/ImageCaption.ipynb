# %% [markdown]
# #### Image captioning AI
#
#
# Datset used - https://www.kaggle.com/datasets/adityajn105/flickr8k (Flickr8k)

# %%
import pandas 
import numpy 
import tensorflow
from tqdm import tqdm
import matplotlib.pyplot as plt
import pickle
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Embedding, Dropout, RepeatVector, TimeDistributed
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import to_categorical
from build import *
import pickle
import numpy as np
from sklearn.model_selection import train_test_split
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

# %%
image_dir = r"C:\Users\Harish Vasanth\Desktop\Lulea\ADL\Lab3\Flickr8k_Dataset"
text_dir = r"C:\Users\Harish Vasanth\Desktop\Lulea\ADL\Lab3\Flickr8k_text"

# %% [markdown]
# - Here we create a dictionary of the format {image_name:Image_discription} and then save it to a pickle file.

# %%
with open("Flickr8k_text/Flickr8k.token.txt", "r") as f:
    raw_caption = f.read()

caption_dict = caption_dictionary(raw_caption)
caption_dict = caption_cleaning(caption_dict)

#Save the caption_dict for future use
with open("captions.pkl", "wb") as f:
    dump(caption_dict, f)

# %% [markdown]
# Lets open a random image and see it's discription

# %%
from PIL import Image
import random

random_index = random.randint(0, len(caption_dict) - 1)
random_image_id = list(caption_dict.keys())[random_index]

random_captions = caption_dict[random_image_id]
image_path = os.path.join(image_dir,random_image_id+".jpg")
image = Image.open(image_path)

# Display the image
plt.imshow(image)   
plt.axis('off')  # Hide axis
description = "\n".join(random_captions)  # Join multiple captions into a single string with line breaks
plt.text(0, -20, description, color='white', fontsize=12, bbox=dict(facecolor='black', alpha=0.5))

plt.show()

# %% [markdown]
# - We need to extract the CNN features for all the images and store them in a pickle file so that can feed it to our final model.
# - We store it in a dictionary form of the format { image_name : Feature_array }

# %%
def feature_extractions(directory):
    """
    Input: directory of images
    Return: A dictionary of features extracted by VGG-16, size 4096.
    """
    
    model = tf.keras.applications.vgg16.VGG16()
    model = keras.models.Model(inputs=model.input, outputs=model.layers[-2].output) #Remove the final layer
    
    features = {}
    for f in tqdm(os.listdir(directory)):
        filename = directory + "/" + f
        identifier = f.split('.')[0]
        
        image = keras.preprocessing.image.load_img(filename, target_size=(224,224))
        arr = keras.preprocessing.image.img_to_array(image, dtype=np.float32)
        arr = arr.reshape((1, arr.shape[0], arr.shape[1], arr.shape[2]))
        arr = keras.applications.vgg16.preprocess_input(arr)
        feature = model.predict(arr, verbose=0)
        features[identifier] = feature
        
        print("feature extraction: {}".format(f))
    return(features)

features = feature_extractions(r"C:\Users\Harish Vasanth\Desktop\Lulea\ADL\Lab3\Flickr8k_Dataset")
with open("features.pkl", "wb") as f:
    dump(features, f)

# %%
# Load image features and descriptions from pickle files
with open(r'C:\Users\Harish Vasanth\Desktop\Lulea\ADL\Lab3\features.pkl', 'rb') as f:
    image_features = pickle.load(f)

with open(r'C:\Users\Harish Vasanth\Desktop\Lulea\ADL\Lab3\captions.pkl', 'rb') as f:
    image_descriptions = pickle.load(f)
    
with open("Flickr8k_text/Flickr8k.token.txt", "r") as f:
    raw_caption = f.read()

# %%
# Clean descriptions

for key in image_descriptions:
    caption = image_descriptions[key]
    temp = []
    for i in caption : 
        caption = i.lower()
        caption = caption.replace('[^A-Za-z]','')
        caption = caption.replace('\s+','')
        caption = '<start> ' + " ".join([word for word in caption.split() if len (word)>1]) + ' <end>'
        temp.append(caption)
    image_descriptions[key] = temp

# %%
image_descriptions
# Out:
# {'1000268201_693b08cb0e': ['<start> child in pink dress is climbing up set of stairs in an entry way <end>',
#   '<start> girl going into wooden building <end>',
#   '<start> little girl climbing into wooden playhouse <end>',
#   '<start> little girl climbing the stairs to her playhouse <end>',
#   '<start> little girl in pink dress going into wooden cabin <end>'],
#  '1001773457_577c3a7d70': ['<start> black dog and spotted dog are fighting <end>',
#   '<start> black dog and tricolored dog playing with each other on the road <end>',
#   '<start> black dog and white dog with brown spots are staring at each other in the street <end>',
#   '<start> two dogs of different breeds looking at each other on the road <end>',
#   '<start> two dogs on pavement moving toward each other <end>'],
#  '1002674143_1b742ab4b8': ['<start> little girl covered in paint sits in front of painted rainbow with her hands in bowl <end>',
#   '<start> little girl is sitting in front of large painted rainbow <end>',
#   '<start> small girl in the grass plays with fingerpaints in front of white canvas with rainbow on it <end>',
#   '<start> there is girl with pigtails sitting in front of rainbow painting <end>',
#   '<start> young girl with pigtails painting outside in the grass <end>'],
#  '1003163366_44323f5815': ['<start> man lays on bench while his dog sits by him <end>',
#   '<start> man lays on the bench to which white dog is also tied <end>',
#   '<start> man sleeping on bench outside with white and black dog sitting next to him <end>',
#   '<start> shirtless man lies on park bench with his dog <end>',
#   '<start> man laying on bench holding leash of dog sitting on ground <end>'],
#  '1007129816_e794419615': ['<start> man in an orange hat starring at something <end>',
#   '<start> man wears an orange hat and glasses <end>',
#   '<start> man with gauges and glasses is wearing blitz hat <end>',
#   '<start> man with glasses is wearing beer can crocheted hat <end>',
#   '<start> the man with pierced ears is wearing glasses and an orange hat <end>'],
#  '1007320043_627395c3d8': ['<start> child playing on rope net <end>',
#   '<start> little girl climbing on red roping <end>',
#   '<start> little girl in pink climbs rope bridge at the park <end>',
#   '<start> small child grips onto the red ropes at the playground <end>',
#   '<start> the small child climbs on red ropes on playground <end>'],
#  '1009434119_febe49276a': ['<start> black and white dog is running in grassy garden surrounded by white fence <end>',
#   '<start> black and white dog is running through the grass <end>',
#   '<start> boston terrier is running in the grass <end>',
#   '<start> boston terrier is running on lush green grass in front of white fence <end>',
#   '<start> dog runs on the green grass near wooden fence <end>'],
#  '1012212859_01547e3f17': ['<start> dog shakes its head near the shore red ball next to it <end>',
#   '<start> white dog shakes on the edge of beach with an orange ball <end>',
#   '<start> dog with orange ball at feet stands on shore shaking off water <end>',
#   '<start> white dog playing with red ball on the shore near the water <end>',
#   '<start> white dog with brown ears standing near water with head turned to one side <end>'],
#  '1015118661_980735411b': ['<start> boy smiles in front of stony wall in city <end>',
#   '<start> little boy is standing on the street while man in overalls is working on stone wall <end>',
#   '<start> young boy runs aross the street <end>',
#   '<start> young child is walking on stone paved street with metal pole and man behind him <end>',
#   '<start> smiling boy in white shirt and blue jeans in front of rock wall with man in overalls behind him <end>'],
#  '1015584366_dfcec3c85a': ['<start> black dog leaps over log <end>',
#   '<start> grey dog is leaping over fallen tree <end>',
#   '<start> large black dog leaps fallen log <end>',
#   '<start> mottled black and grey dog in blue collar jumping over fallen tree <end>',
#   '<start> the black dog jumped the tree stump <end>'],
#  '101654506_8eb26cfb60': ['<start> brown and white dog is running through the snow <end>',
#   '<start> dog is running in the snow <end>',
#   '<start> dog running through snow <end>',
#   '<start> white and brown dog is running through snow covered field <end>',
#   '<start> the white and brown dog is running over the surface of the snow <end>'],
#  '101669240_b2d3e7f17b': ['<start> man in hat is displaying pictures next to skier in blue hat <end>',
#   '<start> man skis past another man displaying paintings in the snow <end>',
#   '<start> person wearing skis looking at framed pictures set up in the snow <end>',
#   '<start> skier looks at framed pictures in the snow next to trees <end>',
#   '<start> man on skis looking at artwork for sale in the snow <end>'],
#  '1016887272_03199f49c4': ['<start> collage of one person climbing cliff <end>',
#   '<start> group of people are rock climbing on rock climbing wall <end>',
#   '<start> group of people climbing rock while one man belays <end>',
#   '<start> seven climbers are ascending rock face whilst another man stands holding the rope <end>',
#   '<start> several climbers in row are climbing the rock while the man in red watches and holds the line <end>'],
#  '1019077836_6fc9b15408': ['<start> brown dog chases the water from sprinkler on lawn <end>',
#   '<start> brown dog plays with the hose <end>',
#   '<start> brown dog running on lawn near garden hose <end>',
#   '<start> dog is playing with hose <end>',
#   '<start> large brown dog running away from the sprinkler in the grass <end>'],
#  '1019604187_d087bf9a5f': ['<start> dog prepares to catch thrown object in field with nearby cars <end>',
#   '<start> white dog is about to catch yellow ball in its mouth <end>',
#   '<start> white dog is about to catch yellow dog toy <end>',
#   '<start> white dog is ready to catch yellow ball flying through the air <end>',
#   '<start> white dog running after yellow ball <end>'],
#  '1020651753_06077ec457': ['<start> black and white dog jumping in the air to get toy <end>',
#   '<start> black and white dog jumps up towards yellow toy <end>',
#   '<start> dog leaps to catch ball in field <end>',
#   '<start> white dog is trying to catch ball in midair over grassy field <end>',
#   '<start> the white dog is playing in green field with yellow toy <end>'],
#  '1022454332_6af2c1449a': ['<start> child and woman are at waters edge in big city <end>',
#   '<start> large lake with lone duck swimming in it with several people around the edge of it <end>',
#   '<start> little boy at lake watching duck <end>',
#   '<start> young boy waves his hand at the duck in the water surrounded by green park <end>',
#   '<start> two people are at the edge of lake facing the water and the city skyline <end>'],
#  '1022454428_b6b660a67b': ['<start> couple and an infant being held by the male sitting next to pond with near by stroller <end>',
#   '<start> couple sit on the grass with baby and stroller <end>',
#   '<start> couple with their newborn baby sitting under tree facing lake <end>',
#   '<start> man and woman care for an infant along the side of body of water <end>',
#   '<start> couple with baby sit outdoors next to their stroller <end>'],
#  '1022975728_75515238d8': ['<start> black dog running in the surf <end>',
#   '<start> black lab with tags frolicks in the water <end>',
#   '<start> dog splashes in the water <end>',
#   '<start> the black dog runs through the water <end>',
#   '<start> this is black dog splashing in the water <end>'],
#  '102351840_323e3de834': ['<start> man drilling hole in the ice <end>',
#   '<start> man is drilling through the frozen ice of pond <end>',
#   '<start> person in the snow drilling hole in the ice <end>',
#   '<start> person standing on frozen lake <end>',
#   '<start> two men are ice fishing <end>'],
#  '1024138940_f1fefbdce1': ['<start> two different breeds of brown and white dogs play on the beach <end>',
#   '<start> two dogs are making turn on soft sand beach <end>',
#   '<start> two dogs playing in the sand at the beach <end>',
#   '<start> two dogs playing together on beach <end>',
#   '<start> two large tan dogs play along sandy beach <end>'],
#  '102455176_5f8ead62d5': ['<start> man uses ice picks and crampons to scale ice <end>',
#   '<start> an ice climber in blue jacket and black pants is scaling frozen ice wall <end>',
#   '<start> an ice climber scaling frozen waterfall <end>',
#   '<start> person in blue and red ice climbing with two picks <end>',
#   '<start> climber climbing an ice wall <end>'],
#  '1026685415_0431cbf574': ['<start> black dog carries green toy in his mouth as he walks through the grass <end>',
#   '<start> black dog carrying something through the grass <end>',
#   '<start> black dog has blue toy in its mouth <end>',
#   '<start> dog in grass with blue item in his mouth <end>',
#   '<start> wet black dog is carrying green toy through the grass <end>'],
#  '1028205764_7e8df9a2ea': ['<start> man and baby are in yellow kayak on water <end>',
#   '<start> man and little boy in blue life jackets are rowing yellow canoe <end>',
#   '<start> man and child kayak through gentle waters <end>',
#   '<start> man and young boy ride in yellow kayak <end>',
#   '<start> man and child in yellow kayak <end>'],
#  '1030985833_b0902ea560': ['<start> black dog and brown dog are jumping up to catch red toy <end>',
#   '<start> black dog and brown dog play with red toy on courtyard <end>',
#   '<start> brown and black lab are outside and the black lab is catching toy in its mouth <end>',
#   '<start> black dog snaps at red and black object as brown dog lunges <end>',
#   '<start> the chocolate lab jumps too late to get the toy as the black lab captures it in the driveway <end>'],
#  '103106960_e8a41d64f8': ['<start> boy with stick kneeling in front of goalie net <end>',
#   '<start> child in red jacket playing street hockey guarding goal <end>',
#   '<start> young kid playing the goalie in hockey rink <end>',
#   '<start> young male kneeling in front of hockey goal with hockey stick in his right hand <end>',
#   '<start> hockey goalie boy in red jacket crouches by goal with stick <end>'],
#  '103195344_5d2dc613a3': ['<start> man in black is sitting next to modern art structure in front of glass building <end>',
#   '<start> man sits and reads newspaper by sculpture outside of an office building <end>',
#   '<start> man sits near large statue <end>',
#   '<start> man sitting in front of metal sculpture in front of building <end>',
#   '<start> the man with the backpack is sitting in buildings courtyard in front of an art sculpture reading <end>'],
#  '103205630_682ca7285b': ['<start> tent is being set up on the ice <end>',
#   '<start> two men are about to enter an ice fishing tent on snow covered lake <end>',
#   '<start> two men setting up blue ice fishing hut on an iced over lake <end>',
#   '<start> two men standing on an ice looking into something covered with blue tarp <end>',
#   '<start> two people standing outside blue tent structure on snowy surface <end>'],
#  '1032122270_ea6f0beedb': ['<start> woman crouches near three dogs in field <end>',
#   '<start> three dogs are playing on grassy hill with blue sky <end>',
#   '<start> three dogs are standing in the grass and person is sitting next to them <end>',
#   '<start> three dogs on grassy hill <end>',
#   '<start> three dogs stand in grassy field while person kneels nearby <end>'],
#  '1032460886_4a598ed535': ['<start> man is standing in front of skyscraper <end>',
#   '<start> man stands in front of skyscraper <end>',
#   '<start> man stands in front of very tall building <end>',
#   '<start> behind the man in red shirt stands large skyscraper <end>',
#   '<start> there is skyscraper in the distance with man walking in front of the camera <end>'],
#  '1034276567_49bb87c51c': ['<start> boy bites hard into treat while he sits outside <end>',
#   '<start> child biting into baked good <end>',
#   '<start> small boy putting something in his mouth with both hands <end>',
#   '<start> the boy eats his food outside at the table <end>',
#   '<start> the boy is eating pizza over tin dish <end>'],
#  '104136873_5b5d41be75': ['<start> people sit on the mountainside and check out the view <end>',
#   '<start> three people are on hilltop overlooking green valley <end>',
#   '<start> three people hang out on top of big hill <end>',
#   '<start> three people overlook green valley <end>',
#   '<start> three people rest on ledge above the moutains <end>'],
#  '1042020065_fb3d3ba5ba': ['<start> boy in green shirt is looking down at many inflatable boats <end>',
#   '<start> boy in green shirt watches kayakers <end>',
#   '<start> boy looks over railing at the many boats and rafts below in the water <end>',
#   '<start> young boy overlooking crowd of inflatable boats <end>',
#   '<start> young boy wearing jersey looks down over ledge at many boats in the water <end>'],
#  '1042590306_95dea0916c': ['<start> man and woman pose for the camera while another man looks on <end>',
#   '<start> man is holding the hand of woman up to his mouth in front of some buildings while another man looks on <end>',
#   '<start> multiracial couple posing for picture <end>',
#   '<start> asian man and blond woman holding hands outdoors man in background watches <end>',
#   '<start> guy in blue shirt biting hand of girl in black striped jacket while another guy watches <end>'],
#  '1045521051_108ebc19be': ['<start> person eats takeout while watching small television <end>',
#   '<start> person sits on the floor and eats in front of television <end>',
#   '<start> television with picture of girl on it <end>',
#   '<start> young man sits on the floor by the television with fast food meal in front of him <end>',
#   '<start> someone is laying in front of the tv eating food <end>'],
#  '1048710776_bb5b0a5c7c': ['<start> couple of several people sitting on ledge overlooking the beach <end>',
#   '<start> group of people sit on wall at the beach <end>',
#   '<start> group of teens sit on wall by beach <end>',
#   '<start> crowd of people at the beach <end>',
#   '<start> several young people sitting on rail above crowded beach <end>'],
#  '1052358063_eae6744153': ['<start> boy takes jump on his skateboard while another boy with skateboard watches <end>',
#   '<start> child is performing skateboard trick while another child with skateboard leans on wall <end>',
#   '<start> little boy skateboarder is doing trick on his board while another young skateboarder watches <end>',
#   '<start> young boy skateboarder jumping on platform on skateboard <end>',
#   '<start> two skateboarders <end>'],
#  '105342180_4d4a40b47f': ['<start> girl paddling down large river as seen from behind her <end>',
#   '<start> woman kayaking down river <end>',
#   '<start> woman paddles boat down river <end>',
#   '<start> woman with paddle <end>',
#   '<start> woman with paddle sits in boat on the water <end>'],
#  '1053804096_ad278b25f1': ['<start> girl in pigtails splashes in the shallow water <end>',
#   '<start> girls plays in the surf <end>',
#   '<start> girl with pigtails is playing in the ocean by the beach <end>',
#   '<start> girl with pigtails plays in the water <end>',
#   '<start> young girl in pigtails plays in the water <end>'],
#  '1055623002_8195a43714': ['<start> group of four children wearing pajamas have pillow fight <end>',
#   '<start> group of kids have pillowfight <end>',
#   '<start> group of young children playing pillow fight on bed <end>',
#   '<start> children having pillow fight <end>',
#   '<start> four children are having pillow fight <end>'],
#  '1055753357_4fa3d8d693': ['<start> two constructions workers sit on beam taking break <end>',
#   '<start> two construction workers are sitting up on the side of building <end>',
#   '<start> two construction workers sitting on an ibeam <end>',
#   '<start> two construction workers take seat on steel beam <end>',
#   '<start> two men take break from construction <end>'],
#  '1056249424_ef2a2e041c': ['<start> the children are playing in the water <end>',
#   '<start> two boys one with yellow and orange ball play in some water in front of field <end>',
#   '<start> two boys play in puddle <end>',
#   '<start> two children play with balloon in mud on sunny day <end>',
#   '<start> two kids are running and playing in some water <end>'],
#  '1056338697_4f7d7ce270': ['<start> blond woman in blue shirt appears to wait for ride <end>',
#   '<start> blond woman is on the street hailing taxi <end>',
#   '<start> woman is signaling is to traffic as seen from behind <end>',
#   '<start> woman with blonde hair wearing blue tube top is waving on the side of the street <end>',
#   '<start> the woman in the blue dress is holding out her arm at oncoming traffic <end>'],
#  '1056359656_662cee0814': ['<start> little girl looking at brochure on train rides <end>',
#   '<start> young blond girl with magizine in her hands <end>',
#   '<start> young girl on train reads book about train rides <end>',
#   '<start> young girl sits on seat and looks at train pamphlet <end>',
#   '<start> child sitting down looking at train ride brochure <end>'],
#  '1056873310_49c665eb22': ['<start> brown dog is running after black dog on rocky shore <end>',
#   '<start> brown dog is running after the black dog <end>',
#   '<start> two dogs playing on beach <end>',
#   '<start> two dogs run across stones near body of water <end>',
#   '<start> two dogs run towards each other on rocky area with water in the background <end>'],
#  '1057089366_ca83da0877': ['<start> boy descends off the end of high diving board <end>',
#   '<start> child jumps off high diving board into the pool <end>',
#   '<start> kid jumps off the diving board and into the swimming pool below <end>',
#   '<start> little kid is jumping off high dive at the pool <end>',
#   '<start> the boy is jumping off high diving board into the pool <end>'],
#  '1057210460_09c6f4c6c1': ['<start> guy stands by window taking his overshirt off <end>',
#   '<start> man in tank top stands next to chrome door <end>',
#   '<start> man puts his shirt on near an elevator <end>',
#   '<start> man stands by an elevator with his head down <end>',
#   '<start> the man is putting on his shirt near an elevator <end>'],
#  '1057251835_6ded4ada9c': ['<start> lightcolored dog runs on the beach <end>',
#   '<start> small yellow dog runs on beach <end>',
#   '<start> tan dog runs on sandy beach <end>',
#   '<start> white dog is running down rocky beach <end>',
#   '<start> light brown dog running along the beach <end>'],
#  '106490881_5a2dd9b7bd': ['<start> boy in his blue swim shorts at the beach <end>',
#   '<start> boy smiles for the camera at beach <end>',
#   '<start> young boy in swimming trunks is walking with his arms outstretched on the beach <end>',
#   '<start> children playing on the beach <end>',
#   '<start> the boy is playing on the shore of an ocean <end>'],
#  '106514190_bae200f463': ['<start> hiker standing high on bluff overlooking the mountains below <end>',
#   '<start> person on ski looks from hill over snow covered landscape <end>',
#   '<start> skier is overlooking snowcovered mountain <end>',
#   '<start> skier is overlooking the beautiful white snow covered landscape <end>',
#   '<start> skier pauses on mountaintop <end>'],
#  '1067180831_a59dc64344': ['<start> black and white dog is attempting to catch yellow and purple object in low cut yard <end>',
#   '<start> black and white dog jumps after yellow toy <end>',
#   '<start> black and white dog jumps to get the frisbee <end>',
#   '<start> black dog is jumping up to catch purple and green toy <end>',
#   '<start> dog jumps to catch toy <end>'],
#  '1067675215_7336a694d6': ['<start> man in blue shorts is laying in the street <end>',
#   '<start> man in blue shorts lays down outside in parking lot <end>',
#   '<start> man laying down in middle of street during heavy traffic <end>',
#   '<start> man lies on mat in parking lot between brown suv and yellow pickup with an open door <end>',
#   '<start> shirtless man is laying down in the middle of busy street <end>'],
#  '1067790824_f3cc97239b': ['<start> white and black dog and brown dog in sandy terrain <end>',
#   '<start> woolly dog chases doberman on beach <end>',
#   '<start> one dog is chasing another one on the beach <end>',
#   '<start> the two large dogs are running through sand <end>',
#   '<start> two large dogs chasing each other at the beach <end>'],
#  '1072153132_53d2bb1b60': ['<start> black and white dog catches toy in midair <end>',
#   '<start> dog and tennis ball <end>',
#   '<start> dog is jumping to catch object thrown at it <end>',
#   '<start> dog leaps while chasing tennis ball through grassy field <end>',
#   '<start> multicolor dog jumping to catch tennis ball in grassy field <end>'],
#  '107318069_e9f2ef32de': ['<start> crowd watching air balloons at night <end>',
#   '<start> group of hot air balloons lit up at night <end>',
#   '<start> people are watching hot air balloons in the park <end>',
#   '<start> people watching hot air balloons <end>',
#   '<start> seven large balloons are lined up at nighttime near crowd <end>'],
#  '1075716537_62105738b4': ['<start> child with helmet on his head rides bike <end>',
#   '<start> little boy rides bike down hill on miniature dirt bike <end>',
#   '<start> young boy in helmet rides bike on the road <end>',
#   '<start> the little boy rides his bicycle in race <end>',
#   '<start> the young boy pedals quickly at bmx race <end>'],
#  '107582366_d86f2d3347': ['<start> group of eight people are gathered around table at night <end>',
#   '<start> group of people gathered around in the dark <end>',
#   '<start> group of people sit around table outside on porch at night <end>',
#   '<start> group of people sit outdoors together at night <end>',
#   '<start> group of people sitting at table in darkened room <end>'],
#  '1075867198_27ca2e7efe': ['<start> man in brown shirt and dark shorts plays on the beach with his two black dogs <end>',
#   '<start> man in shorts with two black dogs holds ball throwing toy at the beach <end>',
#   '<start> man playing with two black dogs on the beach <end>',
#   '<start> man with two dogs on beach <end>',
#   '<start> man at the beach with two dogs <end>'],
#  '1075881101_d55c46bece': ['<start> boy cleans the bubbles off his face <end>',
#   '<start> boy covered in suds has his face wiped clean <end>',
#   '<start> boy is covered in bubbles <end>',
#   '<start> child covered in foam is climbing on black inflatable ramp <end>',
#   '<start> person covered in soapy water is getting cleaned off <end>'],
#  '1077546505_a4f6c4daa9': ['<start> boy in blue shorts slides down slide into pool <end>',
#   '<start> boy in blue swimming trunks slides down yellow slide into wading pool with inflatable toys floating in the water <end>',
#   '<start> boy rides down slide into small backyard pool <end>',
#   '<start> boy sliding down slide into pool with colorful tubes <end>',
#   '<start> child is falling off slide onto colored balloons floating on pool of water <end>'],
#  '1077931201_1e0bb83105': ['<start> man in wetsuit is throwing baby wearing wetsuit up into the air <end>',
#   '<start> man in wetsuit is throwing toddler up in the air and is ready to catch him <end>',
#   '<start> man in water throwing little boy up in the air and waiting for him to come down so he can catch him <end>',
#   '<start> the man is in the pool and throwing small boy into the air <end>',
#   '<start> while water droplets fly man throws little boy up in the air <end>'],
#  '1079274291_9aaf896cc1': ['<start> little boy sticks his tongue out for the camera another boy looks on <end>',
#   '<start> two boys make faces <end>',
#   '<start> two young boys are looking at the camera one smiling the other sticking his tongue out <end>',
#   '<start> two young boys look up at the camera as one sticks out his tongue <end>',
#   '<start> two young boys making silly faces <end>'],
#  '10815824_2997e03d76': ['<start> blonde horse and blonde girl in black sweatshirt are staring at fire in barrel <end>',
#   '<start> girl and her horse stand by fire <end>',
#   '<start> girl holding horse lead behind fire <end>',
#   '<start> man and girl and two horses are near contained fire <end>',
#   '<start> two people and two horses watching fire <end>'],
#  '1082252566_8c79beef93': ['<start> bulldog sheep dog and boxer standing in yard <end>',
#   '<start> large brown dog is pushing small boston terrier with his face while anouther dog watches <end>',
#   '<start> large skinny dog stands near two smaller dogs int the dirt <end>',
#   '<start> there are three dogs starring at ball in the middle of them <end>',
#   '<start> three dogs of various sizes <end>'],
#  '1082379191_ec1e53f996': ['<start> lady and man with no shirt sit on dock <end>',
#   '<start> man and woman are sitting on dock together <end>',
#   '<start> man and woman sitting on dock <end>',
#   '<start> man and woman sitting on deck next to lake <end>',
#   '<start> shirtless man and woman sitting on dock <end>'],
#  '1084040636_97d9633581': ['<start> closeup of white dog that is laying its head on its paws <end>',
#   '<start> large white dog lying on the floor <end>',
#   '<start> white dog has its head on the ground <end>',
#   '<start> white dog is resting its head on tiled floor with its eyes open <end>',
#   '<start> white dog rests its head on the patio bricks <end>'],
#  '1084104085_3b06223afe': ['<start> woman in yellow shirt and green shorts is climbing an artificial red wall whilst wearing safety harness <end>',
#   '<start> woman in blue shorts and white shirt is indoor rock climbing <end>',
#   '<start> the girl is climbing rock wall <end>',
#   '<start> the girl is in harness climbing rocks <end>',
#   '<start> woman climbing an artificial rock wall <end>'],
#  '1087168168_70280d024a': ['<start> boy is jumping on an inflatable ring and girl is watching him <end>',
#   '<start> boy jumping on water jumphouse <end>',
#   '<start> teenage boy is jumping on an inflatable slide <end>',
#   '<start> young boy jumping and young girl seating in an inflatable pool <end>',
#   '<start> two young kids are playing in the water on an inflated toy <end>'],
#  '1087539207_9f77ab3aaf': ['<start> family playing on tractor on beautiful day <end>',
#   '<start> children ride tractor in field <end>',
#   '<start> several children playing on polaris vehicle outdoors <end>',
#   '<start> the children played on the four wheeler in the field <end>',
#   '<start> the four kids are riding on an atv in field <end>'],
#  '1088767354_2acee738cf': ['<start> woman in red costume to the left of man and woman standing together <end>',
#   '<start> woman wearing red costume looks at two other people standing on street <end>',
#   '<start> young woman in red sequined costume and feather stands on the sidewalk <end>',
#   '<start> the girl in the salmon colored bikini is standing next to two young people one is wearing black outfit and the other is drinking pop <end>',
#   '<start> two young people are approached by flamboyant young woman dressed in red bikini and red feathered headress <end>'],
#  '108898978_7713be88fc': ['<start> skiiers walking up the hill through forest <end>',
#   '<start> two men are skiing in the snow in wooded area <end>',
#   '<start> two people wearing yellow jackets crosscountry skiing <end>',
#   '<start> two skiers are making their way through woodland <end>',
#   '<start> two skiers are sliding down trail in the woods <end>'],
#  '108899015_bf36131a57': ['<start> lone skier is making their way up mountain <end>',
#   '<start> skiiers at the top of snow covered hill <end>',
#   '<start> two hikers climbing snowy hill <end>',
#   '<start> two people are on snowcovered mountain <end>',
#   '<start> two people climbing up snowy mountain <end>'],
#  '1089181217_ee1167f7af': ['<start> brown dog running down paved pathway <end>',
#   '<start> brown dog running next to grass <end>',
#   '<start> dog is running down road <end>',
#   '<start> light brown dog runs down path happily <end>',
#   '<start> energetic brown dog running <end>'],
#  '1089755335_0bfbfd30e6': ['<start> mother and children is fishing on boardwalk at night <end>',
#   '<start> woman and three children stand on deck with fishing pole <end>',
#   '<start> woman stands with children on boardwalk at night overlooking the sea <end>',
#   '<start> some people on pier at night with one girl fishing off it <end>',
#   '<start> woman with three children fishing over boardwalk in the evening <end>'],
#  '109202756_b97fcdc62c': ['<start> woman dressed in blue jacket and blue jeans rides brown horse near frozen lake and snowcovered mountain <end>',
#   '<start> woman in blue jacket rides brown pony near water <end>',
#   '<start> woman rides horse near frozen lake in the wintertime <end>',
#   '<start> young blond woman sitting atop brown draft horse in the snowy mountains <end>',
#   '<start> woman blue jacket sits on daft horse near frozen lake <end>'],
#  '109202801_c6381eef15': ['<start> two draft horses pull cart through the snow <end>',
#   '<start> two golden brown horses pull sleigh driven by woman in blue coat <end>',
#   '<start> two horses are pulling woman in cart <end>',
#   '<start> two horses pull carriage driven by woman over snow covered ground <end>',
#   '<start> two horses pulling sled steered by smiling blond woman <end>'],
#  '109260216_85b0be5378': ['<start> person climbing down sheer rock cliff using rope <end>',
#   '<start> person climbs tall flat mountain while holding onto safety rope <end>',
#   '<start> person is climbing rock while holding onto white rope <end>',
#   '<start> person rappels down steep incline <end>',
#   '<start> person wearing red vest climbs up steep rock <end>'],
#  '109260218_fca831f933': ['<start> people stand inside rock dome <end>',
#   '<start> shaft of light in cave shows three spelunkers <end>',
#   '<start> spelunkers pose inside rock cavern while bathed in sunlight from the surface <end>',
#   '<start> three people sit in cave <end>',
#   '<start> three rock climbers are posing on big rocks <end>'],
#  '1093716555_801aacef79': ['<start> group of backpackers lay on the dry ground <end>',
#   '<start> group of hikers are resting on the ground in front of some mountains <end>',
#   '<start> people camp with the mountains in the background <end>',
#   '<start> several hikers rest with their gear in front of mountain <end>',
#   '<start> the group of hikers is resting in front of mountain <end>'],
#  '1093737381_b313cd49ff': ['<start> woman in blue dress stands with chalk portrait of two children playing by stream <end>',
#   '<start> woman standing in front of chalk drawing <end>',
#   '<start> woman stands next to chalk drawing in front of barnlike structure <end>',
#   '<start> woman stands outside near an elaborate chalk illustration <end>',
#   '<start> woman wearing blue dress is drawing picture of boy and girl on the sidewalk with sidewalk chalk <end>'],
#  '1094462889_f9966dafa6': ['<start> brown dog plays in deep pile of snow <end>',
#   '<start> dog looking at the camera in snow <end>',
#   '<start> dog runs through the snow <end>',
#   '<start> tan dog stand in the snow and looks up <end>',
#   '<start> the brown dog is out in the snow <end>'],
#  '1095476286_87d4f8664e': ['<start> boy jumping in fountain <end>',
#   '<start> boy plays in the fountains <end>',
#   '<start> child plays in fountain <end>',
#   '<start> little boy playing in the water <end>',
#   '<start> young boy is jumping through water being sprayed up from the ground <end>'],
#  '1095580424_76f0aa8a3e': ['<start> corgi runs out of tunnel <end>',
#   '<start> dog runs out of tunnel on course <end>',
#   '<start> dog running out of tunnel on obstacle course <end>',
#   '<start> the dog is running out of the tunnel on dog obedience course <end>',
#   '<start> the small brown and white dog is running out of small tunnel <end>'],
#  '1095590286_c654f7e5a9': ['<start> blond dog and black and white dog run in dirt field <end>',
#   '<start> dog chases another dog <end>',
#   '<start> yellow dog and black and white dog are running in the dirt <end>',
#   '<start> two dogs are running in field <end>',
#   '<start> two dogs running around <end>'],
#  '1095980313_3c94799968': ['<start> little girl in blue swimsuit is walking along wooden fence next to sandy beach <end>',
#   '<start> little girl with arms outstretched is posing at the beach <end>',
#   '<start> young girl walks on railing in front of the beach <end>',
#   '<start> little girl in blue swimsuit standing on handrail near beach <end>',
#   '<start> the little girl in the blue bathing suit is posing at the beach <end>'],
#  '1096097967_ac305887b4': ['<start> black and white dog drinking water from water spray <end>',
#   '<start> black and white dog is being soaked with jet of water in blue paddling pool <end>',
#   '<start> dog sticking its face into the shower from garden hose <end>',
#   '<start> small white dog gets sprayed by water <end>',
#   '<start> white and black dog is jumping into pool <end>'],
#  '1096165011_cc5eb16aa6': ['<start> boy smiles underwater <end>',
#   '<start> redheaded boy swimming underwater <end>',
#   '<start> small boy swimming underwater <end>',
#   '<start> smiling boy swims underwater in pool <end>',
#   '<start> the boys smiles underwater at the pool <end>'],
#  '1096395242_fc69f0ae5a': ['<start> boy with toy gun <end>',
#   '<start> little boy in orange shorts playing with toy <end>',
#   '<start> young boy with his foot outstretched aims toy at the camera in front of fireplace <end>',
#   '<start> young child plays with his new lightup toy <end>',
#   '<start> boy with toy gun pointed at the camera <end>'],
#  '109671650_f7bbc297fa': ['<start> boy in yellow shorts is standing on top of cliff <end>',
#   '<start> boy wearing blue and yellow walking on cliff edge <end>',
#   '<start> little boy standing high in the air on rock <end>',
#   '<start> young child is standing alone on some jagged rocks <end>',
#   '<start> child stands near edge of cliff <end>'],
#  '109738763_90541ef30d': ['<start> person on snowmobile in mid jump <end>',
#   '<start> snowmobiler flies through the air <end>',
#   '<start> snowmobile rider flies through the air on his or her machine in front of tall pine trees <end>',
#   '<start> rider jumps snowmobile high in rural area <end>',
#   '<start> the man is up in the air <end>'],
#  '109738916_236dc456ac': ['<start> people are riding around on snowmobiles <end>',
#   '<start> people pose with helmets and goggles on while riding snowmobiles <end>',
#   '<start> several people are taking break while on snowmobiling ride <end>',
#   '<start> three people and two snowmobiles <end>',
#   '<start> two helmeted men sit on yellow snowmobiles while another man stands behind watching <end>'],
#  '109823394_83fcb735e1': ['<start> three people drive atvs <end>',
#   '<start> three people on atvs in brown field turn their heads to look at the camera <end>',
#   '<start> three people on atv outside <end>',
#   '<start> three people on four wheel atv in field <end>',
#   '<start> three people ride their four wheelers through the field <end>'],
#  '109823395_6fb423a90f': ['<start> four wheeler jumping in an empty field <end>',
#   '<start> man on four wheeler is flying through the air <end>',
#   '<start> person is riding an orange atv in large empty field <end>',
#   '<start> man jumping with all terrain vehicle <end>',
#   '<start> man on an atv catching air <end>'],
#  '109823397_e35154645f': ['<start> man jumps gin the air while riding an atv <end>',
#   '<start> man on fourwheeler jumps near small building <end>',
#   '<start> an atv is airborne over field in front of white structure <end>',
#   '<start> person dressed in tan jacket jumps quad over harvested cornfield in front of small out building <end>',
#   '<start> man on four wheeler in the air <end>'],
#  '1100214449_d10861e633': ['<start> boy in striped shirt is jumping in front of water fountain <end>',
#   '<start> boy is jumping off the side of running stone water fountain in front of building <end>',
#   '<start> happy boy is jumping in front od city fountain <end>',
#   '<start> little boy is jumping in front of fountain <end>',
#   '<start> little boy is playfully jumping off the side of fountain <end>'],
#  '1104133405_c04a00707f': ['<start> boy carrying soccer ball <end>',
#   '<start> boy walks with ball tucked under his arm <end>',
#   '<start> boy walks with soccer ball near fence <end>',
#   '<start> boy wearing white tshirt walks on the grass and carries soccer ball <end>',
#   '<start> small boy carries soccer ball on field <end>'],
#  '1105959054_9c3a738096': ['<start> child painting picture <end>',
#   '<start> an artist paints clouds onto canvas <end>',
#   '<start> young girl painting picture <end>',
#   '<start> young girl with braids is painting with water colors on white paper on the wall <end>',
#   '<start> the child paints on large paper with water colors <end>'],
#  '110595925_f3395c8bd6': ['<start> cyclist is riding bicycle on curved road up hill <end>',
#   '<start> man in aerodynamic gear riding bicycle down road around sharp curve <end>',
#   '<start> man on mountain bike is pedaling up hill <end>',
#   '<start> man bicycle up road while cows graze on hill nearby <end>',
#   '<start> the biker is riding around curve in the road <end>'],
#  '1107246521_d16a476380': ['<start> black dog jumping to catch rope toy <end>',
#   '<start> black dog playing fetch with ball of rope <end>',
#   '<start> black dog pounces to get rope toy <end>',
#   '<start> black dog running after his rope toy <end>',
#   '<start> large black dog is playing in grassy yard <end>'],
#  '1107471216_4336c9b328': ['<start> little girl is holding cine camera in front of her face <end>',
#   '<start> young girl is looking through an old fashioned video camera <end>',
#   '<start> young girl steadies her aim with camera <end>',
#   '<start> girl with rosy cheeks and lips holding black toy gun <end>',
#   '<start> there is kid with gun <end>'],
#  '1110208841_5bb6806afe': ['<start> black and white border collie catches frisbee in front of an audience <end>',
#   '<start> brown and white dog catches frisbee in it mouth in front of group of people <end>',
#   '<start> brown and white dug jumping up to catch frisbee while an audience watches <end>',
#   '<start> dog jumps to catch frisbee while many people watch <end>',
#   '<start> an agile dog catches frisbee while crowd of onlookers watches closely <end>'],
#  '1112212364_0c48235fc2': ['<start> baby is sitting on and playing with smooth rocks <end>',
#   '<start> baby is stacking rocks on the beach <end>',
#   '<start> small boy is playing with rocks <end>',
#   '<start> toddler sitting on pile of rocks holding rock at beach <end>',
#   '<start> toddler sits on pile of rocks <end>'],
#  '111497985_38e9f88856': ['<start> kid rock climbing against the backdrop of green valley <end>',
#   '<start> woman in striped shirt climbs up mountain <end>',
#   '<start> young man climbs rocky hill <end>',
#   '<start> the person has striped shirt on and is holding on to rope on mountain <end>',
#   '<start> the person in the striped shirt is mountain climbing <end>'],
#  '111537217_082a4ba060': ['<start> man climbing rock wall <end>',
#   '<start> man climbing the side of cliff <end>',
#   '<start> man is rock climbing <end>',
#   '<start> man with red shoes white shirt and grey pants climbing <end>',
#   '<start> the young man with the white tshirt and jeans is rappeling up the rock wall <end>'],
#  '111537222_07e56d5a30': ['<start> climber wearing blue helmet and headlamp is attached to rope on the rock face <end>',
#   '<start> man climbs rocky wall <end>',
#   '<start> rock climber climbs large rock <end>',
#   '<start> woman in purple snakeskin pants climbs rock <end>',
#   '<start> person with blue helmet and purple pants is rock climbing <end>'],
#  '1115565519_d976d4b1f1': ['<start> child playing with fountain at the beach <end>',
#   '<start> child plays with fountain <end>',
#   '<start> girl looks at fountain that sprays water <end>',
#   '<start> little girl playing in water on frog sculpture <end>',
#   '<start> the little girl is playing with toy in public fountain <end>'],
#  '1115679311_245eff2f4b': ['<start> black dog is jumping over log along beach <end>',
#   '<start> black dog runs along the beach and jumps over wood barrior <end>',
#   '<start> dog is running on the beach <end>',
#   '<start> dog jumping over small wall at beach near the water <end>',
#   '<start> an animal is running on the beach <end>'],
#  '111766423_4522d36e56': ['<start> black and white bird eating seeds out of someone hand <end>',
#   '<start> black and white bird standing on hand <end>',
#   '<start> small bird sits in person hand and eats seeds <end>',
#   '<start> black and white bird standing on hand of someone holding sunflower seeds <end>',
#   '<start> the small bird is clinging to finger of the hand holding the seeds <end>'],
#  '1117972841_2b9261f95f': ['<start> brown dog is running in the sand <end>',
#   '<start> brown dog playing in the sand <end>',
#   '<start> brown dog plays at the beach <end>',
#   '<start> dog is standing in the sand <end>',
#   '<start> dog running fast in the sand <end>'],
#  '1118557877_736f339752': ['<start> little boy stands in the surf <end>',
#   '<start> small child wades through the water while being guided by another person <end>',
#   '<start> young boy laughs while splashing in the ocean <end>',
#   '<start> young boy wearing colorful bathing suit splashing in the ocean <end>',
#   '<start> young child splashing in water <end>'],
#  '1119015538_e8e796281e': ['<start> little tan dog with large ears running through the grass <end>',
#   '<start> playful dog is running through the grass <end>',
#   '<start> small dogs ears stick up as it runs in the grass <end>',
#   '<start> the small dog is running across the lawn <end>',
#   '<start> this is small beige dog running through grassy field <end>'],
#  '1119418776_58e4b93eac': ['<start> black and white dog is running through the field <end>',
#   '<start> black brown and white dog running through field <end>',
#   '<start> brown black and white dog is running through large field with its mouth open <end>',
#   '<start> dog running in field <end>',
#   '<start> dog with its mouth open running through field torwards the camera <end>'],
#  '1119463452_69d4eecd08': ['<start> girl in pink swimsuit in pool <end>',
#   '<start> girl swimming in pool <end>',
#   '<start> little girl in pink bathing suit swimming in pool <end>',
#   '<start> little girl swimming in pool <end>',
#   '<start> smiling little girl swimming in outdoor pool <end>'],
#  '1121416483_c7902d0d49': ['<start> child is standing on her head <end>',
#   '<start> little girl standing on her head <end>',
#   '<start> small child doing handstand on bed <end>',
#   '<start> young girl does handstand on bed with blue sheets <end>',
#   '<start> the girl is upside down on bed <end>'],
#  '112178718_87270d9b4d': ['<start> guy stands in the sand with snowboard behind him <end>',
#   '<start> man holds surfboard on the beach <end>',
#   '<start> man holds his snowboard in the sand <end>',
#   '<start> man with his surfboard stands in the sand <end>',
#   '<start> man is standing on white sand and holding snowboard <end>'],
#  '112243673_fd68255217': ['<start> people on atvs and dirt bikes are traveling along worn path in field surrounded by trees <end>',
#   '<start> three people are riding around on atv and motorcycles <end>',
#   '<start> three people on motorbikes follow trail through dry grass <end>',
#   '<start> three people on two dirtbikes and one fourwheeler are riding through brown grass <end>',
#   '<start> three people ride offroad bikes through field surrounded by trees <end>'],
#  '1122944218_8eb3607403': ['<start> baby in white garment holds flag with crescent moon and star <end>',
#   '<start> baby is holding small black flag with moon and star on it <end>',
#   '<start> baby wearing white gown waves muslim flag <end>',
#   '<start> little toddler dressed in white is smiling while lady helps him wave flag <end>',
#   '<start> baby in white outfit holding black and white flag <end>'],
#  '1124448967_2221af8dc5': ['<start> half naked man is sleeping on his chair outdoors <end>',
#   '<start> an older man sits back and relaxes on patio outside an adobe building where many bicycles are propped <end>',
#   '<start> shirtless man in white cap relaxes in deck chair close to three parked bicycles <end>',
#   '<start> man relaxing in folding chair on the street <end>',
#   '<start> topless old man wearing slippers navy blue pants and white hat while reclining in chair outside <end>'],
#  '1129704496_4a61441f2c': ['<start> brown and white and black and white dog hauling in floating toy from the ocean <end>',
#   '<start> both dogs retrieve the play toy from the water <end>',
#   '<start> two dogs in the ocean playing with toy <end>',
#   '<start> two dogs run through the water with rope in their mouths <end>',
#   '<start> two dogs tug at chew toy in the surf <end>'],
#  '1130017585_1a219257ac': ['<start> there are three young people one dark haired holding bottled drink one with head tilted back and finger in her mouth and one with spiked hair <end>',
#   '<start> the young people party in the streets <end>',
#   '<start> three girls make faces as one takes drink while they stand in busy street <end>',
#   '<start> three women on the street drinking and posing <end>',
#   '<start> three young women pose for the camera at parade <end>'],
#  '1130369873_d80a1aa59c': ['<start> brown dog is running through neckdeep water carrying tennis ball <end>',
#   '<start> brown dog splashes in the water while carrying ball in its mouth <end>',
#   '<start> brown dog swims through water outdoors with tennis ball in its mouth <end>',
#   '<start> red dog holding ball splashes through vegetation filled water <end>',
#   '<start> brown dog with tennis ball in mouth in water and bushes <end>'],
#  '1130401779_8c30182e3e': ['<start> two brown dogs are creating large splashes as they run in river <end>',
#   '<start> two brown dogs in the water <end>',
#   '<start> two brown dogs running through water <end>',
#   '<start> two brown dogs runs through the water <end>',
#   '<start> two dogs splash through the water <end>'],
#  '1131155939_b4b457b05e': ['<start> black dog runs into the ocean next to pile of seaweed <end>',
#   '<start> black lav runs into the water on the beach with swimmers in the distance and sea kelp in the foreground <end>',
#   '<start> dog at the shore of an ocean with seaweed in foreground <end>',
#   '<start> dog is running in the waves at the beach <end>',
#   '<start> pile of seaweed sits on the sand behind it big black dog is running in the water <end>'],
#  '1131340021_83f46b150a': ['<start> young boy runs while wearing sandals <end>',
#   '<start> little boy in striped shirt and brown shorts is running <end>',
#   '<start> the little boy in short sleeved shirt and shorts is running outside <end>',
#   '<start> the little boy is wearing black pinstripe shirt and walking on deck <end>',
#   '<start> young boy running outside on the pavement <end>'],
#  '1131800850_89c7ffd477': ['<start> brown and white dog stands outside while it snows <end>',
#   '<start> dog is looking at something near the water <end>',
#   '<start> furry dog attempts to dry itself by shaking the water off its coat <end>',
#   '<start> white and brown dog shaking its self dry <end>',
#   '<start> the large brown and white dog shakes off water <end>'],
#  '1131804997_177c3c0640': ['<start> two men are sitting on the ground and going through their backpacks <end>',
#   '<start> two men sitting in front of railing are looking at something <end>',
#   '<start> two men with backpacks placed in front of them sitting in front of railing <end>',
#   '<start> two men with backpacks are sitting on cardboard along railing <end>',
#   '<start> two older men with backpacks sit at bus station <end>'],
#  '1131932671_c8d17751b3': ['<start> boy is jumping on bed <end>',
#   '<start> boy jumped up from the green bed <end>',
#   '<start> boy jumps from one bed to another <end>',
#   '<start> small child is jumping on bed <end>',
#   '<start> the boy in blue shorts is bouncing on the bed <end>'],
#  '1132772170_600610c5df': ['<start> child leaping from bed to bed behind the back of man <end>',
#   '<start> man is standing with his arms folded looking at something while the person behind him is jumping onto one of the two beds in the room <end>',
#   '<start> man wearing yellow shirt standing in the middle of two beds that boy is jumping on in the background <end>',
#   '<start> young child jumping on the bed as man looks the other way <end>',
#   '<start> man standing in the bedroom with little boy jumping into bed <end>'],
# ...
#   '<start> little girl wearing purple dress looks down at the camera <end>',
#   '<start> young girl climbs rock wall in purple dress <end>',
#   '<start> young girl wears purple dress <end>'],
#  '2087317114_cf06df5aa5': ['<start> mani is kayaking down some calmer rapids <end>',
#   '<start> man in small kayak is floating down the river <end>',
#   '<start> man in yellow jacket is floating on the river in green kayak <end>',
#   '<start> man smiles in his blue and green kayak <end>',
#   '<start> man wearing helmet in pyranha kayak floats down some river rapids <end>'],
#  '2087640654_1a84577a44': ['<start> blonde dog is digging deep hole in the ground and its tail is up in the air <end>',
#   '<start> dog half way in hole in the ground <end>',
#   '<start> dog is digging large hole in yard to find something <end>',
#   '<start> dog is digging in the ground and half of his body is under the ground <end>',
#   '<start> the rear end of an animal whose front end is underground <end>'],
#  '2088120475_d6318364f5': ['<start> person dressed up as snowman is walking through crowd of people <end>',
#   '<start> five cold people in the snowstorm one wearing snowman head <end>',
#   '<start> people pose for picture in the snow <end>',
#   '<start> three young people pose by snowman in red tie <end>',
#   '<start> two couples pose with snowman <end>'],
#  '2088460083_42ee8a595a': ['<start> broken down hummer gets towed on truck bed <end>',
#   '<start> damaged vehicle is carried by repair truck in nighttime scene <end>',
#   '<start> flat bed truck in parking lot with an army vehicle on its bed <end>',
#   '<start> an old beatup jeep being towed away <end>',
#   '<start> dirty suv sits on the bed of tow truck at night <end>'],
#  '2088532947_c628e44c4a': ['<start> the girl in the white shirt has bracelet on and has her arm around the girl in the peach shirt <end>',
#   '<start> the two girls laid on the grass together <end>',
#   '<start> two little girls are laying on the grass smiling <end>',
#   '<start> two young girls holding each other on the grassy ground <end>',
#   '<start> two young girls hug each other in the grass <end>'],
#  '2088910854_c6f8d4f5f9': ['<start> large man is wearing headband with mistletoe attached to it <end>',
#   '<start> man in sweatshirt and cap wears flower on his head <end>',
#   '<start> man wearing black knit cap with red and white striped headband with flower on top <end>',
#   '<start> an man with black ski cap and red and white headband looks into the distance <end>',
#   '<start> man wearing black hat with christmas theme <end>'],
#  '2089122314_40d5739aef': ['<start> dog running with newspaper in its mouth <end>',
#   '<start> dog runs down the street carrying newspaper <end>',
#   '<start> dog with newspaper in his mouth runs down paved path <end>',
#   '<start> fluffy tricolored dog is running down the road with paper in its mouth <end>',
#   '<start> an australian shepherd dog carrying newspaper in his mouth <end>'],
#  '2089350172_dc2cf9fcf6': ['<start> three black dogs are swimming through some murky brown water one with yellow object in its mouth <end>',
#   '<start> three black dogs swimming in dirty water <end>',
#   '<start> three dark dogs swimming and one of them has ball <end>',
#   '<start> three dogs are up to their necks in water <end>',
#   '<start> three dogs swim in the water <end>'],
#  '2089426086_7acc98a3a8': ['<start> girl in hooded jacket presents cake with candles <end>',
#   '<start> girl in hood jacket holds birthday cake with many candles <end>',
#   '<start> girl in winter coat with birthday cake <end>',
#   '<start> girl is holding birthday cake <end>',
#   '<start> young girl holding cake with candles dressed in heavy coat <end>'],
#  '2089442007_6fc798548c': ['<start> brown dog is walking in the water <end>',
#   '<start> brown dog takes cautious steps in the calm waters with sandy bottom <end>',
#   '<start> brown dog wades in the water <end>',
#   '<start> dog with red fur stands in body of water <end>',
#   '<start> large golden colored dog is walking through water <end>'],
#  '2089539651_9e518ec7de': ['<start> hiker with two hiking poles stands on hillside with view of the city below him <end>',
#   '<start> hiker with two sticks is standing on path that is high up on hill <end>',
#   '<start> hiking man stands on cliff overlooking city <end>',
#   '<start> man hikes on dirt path high above city <end>',
#   '<start> person holding poles is standing on rock ledge with bushes on each side overlooking mountains <end>'],
#  '2089542487_b4c1ee7025': ['<start> hiker is ready to take on rugged outdoor trail <end>',
#   '<start> lone hiker on dirt hiking trail with hat and sunglasses on with trees in the background <end>',
#   '<start> man in shorts is hiking in dry region <end>',
#   '<start> man stops for picture with the scenery during his hike <end>',
#   '<start> the man is posing for picture in the desert wearing green shirt and hat and holding metal detector <end>'],
#  '2089555297_95cf001fa7': ['<start> man in hat with long sleeves and long pants stands overlooking city <end>',
#   '<start> man stands on cliff overlooking city <end>',
#   '<start> man with backpack and hat is standing by high cliff where you can see for miles <end>',
#   '<start> hiker standing on top of rock overlooking town <end>',
#   '<start> the man wearing backpack and hat stands on ledge overlooking city <end>'],
#  '2090327868_9f99e2740d': ['<start> woman little boy and tiny baby are standing in front of cow statue <end>',
#   '<start> woman and two small children posing in front of large cow statue <end>',
#   '<start> woman gives baby to small child to hold as they stand in front of cow statue <end>',
#   '<start> woman stands with two children near decorated bull statue <end>',
#   '<start> the woman and children are standing next to statue of cow <end>'],
#  '2090339522_d30d2436f9': ['<start> man in green hat is someplace up high <end>',
#   '<start> man in green hat is taking self portrait <end>',
#   '<start> man in hat at scenic overlook <end>',
#   '<start> man wearing green canvas hat with distnat city in the background <end>',
#   '<start> man with green hate and sunglasses on high up peak <end>'],
#  '2090386465_b6ebb7df2c': ['<start> woman and man in winter gear stand <end>',
#   '<start> three adults wearing cold weather gear <end>',
#   '<start> two people are wearing heavy clothing <end>',
#   '<start> two people in winter clothing <end>',
#   '<start> two women bundled up on snowy day <end>'],
#  '2090387793_274ab4cf7d': ['<start> boy wearing black walks down the street with his hands in fists <end>',
#   '<start> teenage boy dressed in black stands on snowy street <end>',
#   '<start> teenage boy wearing all black tries to look tough with cheap jewelry on <end>',
#   '<start> young man wearing black hat and jacket is walking outside <end>',
#   '<start> punk rock teenager walks with mean look on his face <end>'],
#  '2090545563_a4e66ec76b': ['<start> the boy laying face down on skateboard is being pushed along the ground by another boy <end>',
#   '<start> two girls play on skateboard in courtyard <end>',
#   '<start> two people play on long skateboard <end>',
#   '<start> two small children in red shirts playing on skateboard <end>',
#   '<start> two young children on skateboard going across sidewalk <end>'],
#  '2090723611_318031cfa5': ['<start> dogs walking in the grassy field <end>',
#   '<start> large fluffy grey dog standing in grass in front of brown dog <end>',
#   '<start> one dog standing in some grass with his tongue hanging out and tan dog in the background <end>',
#   '<start> two dogs of different breeds are standing in pasture <end>',
#   '<start> two dogs stand in the grass <end>'],
#  '2090997177_76d482b158': ['<start> black dog bounds across the sand <end>',
#   '<start> dog walking across the desert <end>',
#   '<start> short black dog is walking over barren landscape <end>',
#   '<start> small black dog running across the sand <end>',
#   '<start> small black dog walks in the sand <end>'],
#  '2091171488_c8512fec76': ['<start> female wearing pink gloves and brown jacket is smiling in the snow <end>',
#   '<start> woman standing in the snow with people in the background <end>',
#   '<start> young woman in spring coat and purple gloves stands in falling snow <end>',
#   '<start> young woman looks happy in winter clothes while it snows <end>',
#   '<start> young asian woman with pink gloves stands in the snow <end>'],
#  '2092177624_13ab757e8b': ['<start> boy in african clothing runs across concrete wall <end>',
#   '<start> little boy with green shirt is running on rock ledge <end>',
#   '<start> an african boy in large green shirt is running barefoot along wall <end>',
#   '<start> young boy dressed in green running along smooth stone wall near wooded area <end>',
#   '<start> boy in green tunic on rock wall <end>'],
#  '2092419948_eea8001d0f': ['<start> long haired man walking away beside canal whist holding onto railing <end>',
#   '<start> man walks down path next to waterway <end>',
#   '<start> person walks by some bluegreen water while holding rail <end>',
#   '<start> person with long ponytail walks along waterway under tunnel <end>',
#   '<start> the man with long hair is walking along storm drain <end>'],
#  '2092870249_90e3f1855b': ['<start> man lies on street with his head and shoulders under parked car that is jacked up <end>',
#   '<start> man looks under car on wet street <end>',
#   '<start> man works on car <end>',
#   '<start> person lies half under car facedown <end>',
#   '<start> person underneath car with jack <end>'],
#  '2094323311_27d58b1513': ['<start> dog places his head on man face <end>',
#   '<start> dog snuggles with man in sunglasses <end>',
#   '<start> dog with blue collar is licking man who wearing large tinted sunglasses <end>',
#   '<start> large brown dog with blue collar is resting his chin on man face <end>',
#   '<start> an orange dog is licking man wearing red sunglasses <end>'],
#  '2094543127_46d2f1fedf': ['<start> girl holding crocodile mouth closed <end>',
#   '<start> girl is posed over statue of dangerous animal <end>',
#   '<start> girl sits on what appears to be crocodile <end>',
#   '<start> girl sitting on top of crocodile <end>',
#   '<start> girl with red hair is sitting on crocodile holding its jaw <end>'],
#  '2094810449_f8df9dcdf7': ['<start> boy stands in the ocean lifting up his shorts <end>',
#   '<start> child in blue shorts is standing ankle deep in the water <end>',
#   '<start> little boy in blue shorts glasses and coat stands in the surf <end>',
#   '<start> the kid is wearing blue jacket and standing in shallow beach water <end>',
#   '<start> the small child wades ankle deep in the water on the shoreline <end>'],
#  '2095007523_591f255708': ['<start> baby looks through his crib <end>',
#   '<start> baby surrounded by some toys looks out of playpen <end>',
#   '<start> baby in playpen with wide eyes <end>',
#   '<start> baby looking through playpen bars at camera <end>',
#   '<start> the infant is laying on its stomach in crib looking up at the camera <end>'],
#  '2095078658_c14ba89bc2': ['<start> dog runs through snow in front of the woods <end>',
#   '<start> large dog running in snow <end>',
#   '<start> the dog runs through the snow <end>',
#   '<start> the german shepherd dog is running through the snow <end>',
#   '<start> the german shepherd is running through the white snow <end>'],
#  '2095435987_1b7591d214': ['<start> dog lying on its back in the sand <end>',
#   '<start> white and brown dog rolls on its back in the sand <end>',
#   '<start> the dog rolls over to scratch its back in the sand <end>',
#   '<start> the white and brown dog is rolling in the sand <end>',
#   '<start> the white dog is on its back in the sand with paws in the air <end>'],
#  '2095444126_201ff9f222': ['<start> dog is shaking off water <end>',
#   '<start> dog shakes his head <end>',
#   '<start> dog shakes off water <end>',
#   '<start> dog shakes off water and gets contorted <end>',
#   '<start> the dog is shaking water off of his body <end>'],
#  '2095478050_736c4d2d28': ['<start> man and boy play music as little girls watch <end>',
#   '<start> man is playing guitar with child playing harmonica while three young girls watch <end>',
#   '<start> three children watch man onstage playing guitar <end>',
#   '<start> three little girls look on as boy plays the harmonica with an adult guiutarist sitting beside him <end>',
#   '<start> three little girls watch band <end>'],
#  '209605542_ca9cc52e7b': ['<start> climber wearing red headband is pulling himself up some grey rocks high above some green foliage <end>',
#   '<start> man in headband climbing rock <end>',
#   '<start> man with red headband climbing rock cliff looming over greenery <end>',
#   '<start> man climbing sheet rock face <end>',
#   '<start> man in red headband climbing rock <end>'],
#  '2096771662_984441d20d': ['<start> man looks through his binoculars while another man holds drink <end>',
#   '<start> man with thermos is standing next to man who is gazing through binoculars <end>',
#   '<start> two men are standing together while one looks through binoculars <end>',
#   '<start> two men look out as one is holding binoculars <end>',
#   '<start> two people standing next to each other with mountains in the distance <end>'],
#  '2097398349_ff178b3f1b': ['<start> hiker waves to the camera as he standing in front of snowcapped mountains <end>',
#   '<start> man stands on the snow near the mountains <end>',
#   '<start> person poses in the snow <end>',
#   '<start> person stands in the snow at the top of mountian arms raised <end>',
#   '<start> skier in the mountains <end>'],
#  '2097403787_77a154f5b9': ['<start> lone person standing on some rocks with large snowy mountains in the background <end>',
#   '<start> man is standing on the rocky ground in front of the mountain <end>',
#   '<start> man standing in front of an icy mountain <end>',
#   '<start> the person is standing by the water in front of the snow topped mountains <end>',
#   '<start> the traveller pauses in front of the mountain view <end>'],
#  '2097407245_c798e0dcaf': ['<start> man in winter jacket and knit cap stand with his arms up at his side in snow landscape <end>',
#   '<start> man is standing on dirt with his hands in the air with mountains and snow behind him <end>',
#   '<start> man raises his arms on rocky beach <end>',
#   '<start> one lone man with fist in the air with large rocky mountains in the background <end>',
#   '<start> man with outstretched arms standing on snowcovered rocks <end>'],
#  '2097420505_439f63c863': ['<start> male hiker wearing green jacket is posing next to large glacier <end>',
#   '<start> man with camera and an ice structure behind him <end>',
#   '<start> man with camera crouching on ice <end>',
#   '<start> man with camera kneels in front of giant hill of snow <end>',
#   '<start> the mountain climber prepares to take photo <end>'],
#  '2097489021_ca1b9f5c3b': ['<start> girl in ballet fairy costume is touched by wand <end>',
#   '<start> young girl performing the nutcracker <end>',
#   '<start> the little girl is standing on stage dressed up as pink fairy <end>',
#   '<start> the tiny girl dressed in butterfly ballet costume waves her wand near nutcracker statue <end>',
#   '<start> young girl waving turquiose leotard and pink tutu with wings waving wand <end>'],
#  '2098174172_e57d86ea03': ['<start> hiker is posing in front of snowy mountains <end>',
#   '<start> hiker is standing in before the mountain holding two walking sticks <end>',
#   '<start> man stands in front of snow covered mountains <end>',
#   '<start> man with two ski poles stands near mountaintop <end>',
#   '<start> the man wears green hat and jacket while standing in front of mountain <end>'],
#  '2098418613_85a0c9afea': ['<start> brown chow mix dog is standing in front of van with euro plats in the middle of messy yard <end>',
#   '<start> brown dog standing in muddy yard <end>',
#   '<start> brown dogs walks near green van and some junk <end>',
#   '<start> large brown dog stands in front of green van in the yard of house <end>',
#   '<start> yellow dog is standing in front of green car and next to toilet <end>'],
#  ...}

# %%
all_captions = []
for key in image_descriptions:
    for caption in image_descriptions[key]:
        all_captions.append(caption)

# %%
# tokenize the text
tokenizer = Tokenizer()
tokenizer.fit_on_texts(all_captions)
vocab_size = len(tokenizer.word_index) + 1
# get maximum length of the caption available
max_length = max(len(caption.split()) for caption in all_captions)
max_length
print("Vocab size is  : {} ".format(vocab_size))
print("Max size of captions is  : {} ".format(max_length))
# Out:
# Vocab size is  : 8809
# Max size of captions is  : 34

# %%
# create data generator to get data in batch (avoids session crash)
from tensorflow.keras.applications.vgg16 import VGG16, preprocess_input
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Model
from tensorflow.keras.utils import to_categorical, plot_model
from tensorflow.keras.layers import Input, Dense, LSTM, Embedding, Dropout, add

def data_generator(data_keys, mapping, features, tokenizer, max_length, vocab_size, batch_size):
    # loop over images
    X1, X2, y = list(), list(), list()
    n = 0
    while 1:
        for key in data_keys:
            n += 1
            captions = mapping[key]
            # process each caption
            for caption in captions:
                # encode the sequence
                seq = tokenizer.texts_to_sequences([caption])[0]
                # split the sequence into X, y pairs
                for i in range(1, len(seq)):
                    # split into input and output pairs
                    in_seq, out_seq = seq[:i], seq[i]
                    # pad input sequence
                    in_seq = pad_sequences([in_seq], maxlen=max_length)[0]
                    # encode output sequence
                    out_seq = to_categorical([out_seq], num_classes=vocab_size)[0]
                    
                    # store the sequences
                    X1.append(features[key][0])
                    X2.append(in_seq)
                    y.append(out_seq)
            if n == batch_size:
                X1, X2, y = np.array(X1), np.array(X2), np.array(y)
                yield {"image": X1, "text": X2}, y
                X1, X2, y = list(), list(), list()
                n = 0
                
# encoder model
# image feature layers
inputs1 = Input(shape=(4096,), name="image")
fe1 = Dropout(0.4)(inputs1)
fe2 = Dense(256, activation='relu')(fe1)
# sequence feature layers
inputs2 = Input(shape=(max_length,), name="text")
se1 = Embedding(vocab_size, 256, mask_zero=True)(inputs2)
se2 = Dropout(0.4)(se1)
se3 = LSTM(256)(se2)

# decoder model
decoder1 = add([fe2, se3])
decoder2 = Dense(256, activation='relu')(decoder1)
outputs = Dense(vocab_size, activation='softmax')(decoder2)

model = Model(inputs=[inputs1, inputs2], outputs=outputs)
model.compile(loss='categorical_crossentropy', optimizer='adam')

# plot the model
plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
#### Pre process for key errors :

error_keys = []

for key in image_features:
    check = 0
    for key2 in image_descriptions:
        if (key == key2):
            check = 1
    
    if check != 1 :
        print("Key not present in image_description : {}".format(key))
        error_keys.append(key)
        
        

for key in image_descriptions:
    check = 0
    for key2 in image_features:
        if (key == key2):
            check = 1
    
    if check != 1 :
        print("Key not present in image_features : {}".format(key))
        error_keys.append(key)
        

for i in error_keys:
    if i in image_descriptions :
        del image_descriptions[i]
        print("Key {} has been deleted from image_discriptions".format(key))

        
    if i in image_features:
        del image_features[i]
        print("Key {} has been deleted from image_features".format(key))
# Out:
# Key not present in image_features : 2258277193_586949ec62
# Key 997722733_0cb5439472 has been deleted from image_discriptions

# %%
assert (len(image_features) == len(image_descriptions))

# %%
image_ids = list(image_descriptions.keys())
split = int(len(image_ids) * 0.90)
train = image_ids[:split]
test = image_ids[split:]

# %%
# train the model
epochs = 20
batch_size = 32
steps = len(train) // batch_size

for i in range(epochs):
    # create data generator
    generator = data_generator(train, image_descriptions, image_features, tokenizer, max_length, vocab_size, batch_size)
    # fit for one epoch
    model.fit(generator, epochs=1, steps_per_epoch=steps, verbose=1)
# Out:
# 227/227 [==============================] - 440s 2s/step - loss: 4.6340
# 227/227 [==============================] - 502s 2s/step - loss: 3.8178
# 227/227 [==============================] - 513s 2s/step - loss: 3.4703
# 227/227 [==============================] - 619s 3s/step - loss: 3.2297
# 227/227 [==============================] - 566s 2s/step - loss: 3.0490
# 227/227 [==============================] - 1318s 6s/step - loss: 2.9141
# 227/227 [==============================] - 357s 2s/step - loss: 2.8051
# 227/227 [==============================] - 370s 2s/step - loss: 2.7179
# 227/227 [==============================] - 358s 2s/step - loss: 2.6390
# 227/227 [==============================] - 359s 2s/step - loss: 2.5725
# 227/227 [==============================] - 357s 2s/step - loss: 2.5089
# 227/227 [==============================] - 357s 2s/step - loss: 2.4518
# 227/227 [==============================] - 364s 2s/step - loss: 2.4012
# 227/227 [==============================] - 376s 2s/step - loss: 2.3563
# 227/227 [==============================] - 435s 2s/step - loss: 2.3134
# 227/227 [==============================] - 603s 3s/step - loss: 2.2733
# 227/227 [==============================] - 571s 3s/step - loss: 2.2343
# 227/227 [==============================] - 482s 2s/step - loss: 2.2031
# 227/227 [==============================] - 515s 2s/step - loss: 2.1768
# 227/227 [==============================] - 564s 2s/step - loss: 2.1479

# %%
model_dir = r"C:\Users\Harish Vasanth\Desktop\Lulea\ADL\Lab3\models"
model.save(os.path.join(model_dir,"model_alpha.h5"))
# Out:
# c:\Users\Harish Vasanth\Desktop\GroundUP\.conda\lib\site-packages\keras\src\engine\training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
def idx_to_word(integer, tokenizer):
    for word, index in tokenizer.word_index.items():
        if index == integer:
            return word
    return None
# generate caption for an image
def predict_caption(model, image, tokenizer, max_length):
    # add start tag for generation process
    in_text = 'startseq'
    # iterate over the max length of sequence
    for i in range(max_length):
        # encode input sequence
        sequence = tokenizer.texts_to_sequences([in_text])[0]
        # pad the sequence
        sequence = pad_sequences([sequence], max_length)
        # predict next word
        yhat = model.predict([image, sequence], verbose=0)
        # get index with high probability
        yhat = np.argmax(yhat)
        # convert index to word
        word = idx_to_word(yhat, tokenizer)
        # stop if word not found
        if word is None:
            break
        # append word as input for generating next word
        in_text += " " + word
        # stop if we reach end tag
        if word == 'endseq':
            break
      
    return in_text

from nltk.translate.bleu_score import corpus_bleu
# validate with test data
actual, predicted = list(), list()

for key in tqdm(test):
    # get actual caption
    captions = image_descriptions[key]
    # predict the caption for image
    y_pred = predict_caption(model, image_features[key], tokenizer, max_length) 
    # split into words
    actual_captions = [caption.split() for caption in captions]
    y_pred = y_pred.split()
    # append to the list
    actual.append(actual_captions)
    predicted.append(y_pred)
    
# calcuate BLEU score
print("BLEU-1: %f" % corpus_bleu(actual, predicted, weights=(1.0, 0, 0, 0)))
print("BLEU-2: %f" % corpus_bleu(actual, predicted, weights=(0.5, 0.5, 0, 0)))
# Out:
#   0%|          | 0/810 [00:00<?, ?it/s]
# 100%|██████████| 810/810 [1:50:27<00:00,  8.18s/it]
# BLEU-1: 0.117566
# BLEU-2: 0.060415

# %%
from PIL import Image
import matplotlib.pyplot as plt
def clean_caption(text):
    end_index = text.lower().find("end")
    
    if end_index != -1:
        # Extract the part of the text before the first "end"
        cleaned_text = text[:end_index]
    else:
        # If "end" is not found, return the original text
        cleaned_text = text
    
    return cleaned_text
    

def generate_caption(image_name):
    # load the image
    # image_name = "1001773457_577c3a7d70.jpg"
    image_id = image_name.split('.')[0]
    img_path = os.path.join(r"C:\Users\Harish Vasanth\Desktop\Lulea\ADL\Lab3\Flickr8k_Dataset", image_name)
    image = Image.open(img_path)
    captions = image_descriptions[image_id]
    print('---------------------Actual---------------------')
    for caption in captions:
        print(caption)
    # predict the caption
    y_pred = predict_caption(model, image_features[image_id], tokenizer, max_length)
    print('--------------------Predicted--------------------')
    print(y_pred)
    y_pred = clean_caption(y_pred)
    print('--------------------Cleaned--------------------')
    print(y_pred)
    plt.imshow(image)

# %% [markdown]
# #### Sample prediction on a random image

# %%
import random 

index = random.randint(0, len(image_descriptions))
random_image_id = list(image_descriptions.keys())[index]
generate_caption(random_image_id+".jpg")
# Out:
# ---------------------Actual---------------------
# <start> man and skateboard on top of barrel <end>
# <start> man doing some sort of trick <end>
# <start> man in black perfors on skateboard <end>
# <start> man is jumping over barrel on skateboard <end>
# <start> man on skateboard on top of rust colored barrel in darkened area <end>
# --------------------Predicted--------------------
# startseq the man does trick on his skateboard end end end end end end end end end end end end end end end end end end end end end end end end end end end
# --------------------Cleaned--------------------
# startseq the man does trick on his skateboard
