# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import keras
import matplotlib.pyplot as plt
import seaborn as sns

# %%
genres =  ['action_series.csv', 'adventure_series.csv','animation_series.csv','biography_series.csv', 'comedy_series.csv','crime_series.csv','documentary_series.csv','drama_series.csv','family_series.csv','fantasy_series.csv','horror_series.csv','history_series.csv','music_series.csv','mystery_series.csv','romance_series.csv','sci-fi_series.csv','sport_series.csv','superhero_series.csv','thriller_series.csv','war_series.csv','western_series.csv']
df = pd.concat(map(pd.read_csv, genres))
df2 = df.drop_duplicates(subset=['Title'])

# %%
# checking for NA values
fig, ax = plt.subplots(figsize=(5,5))   
sns.heatmap(df2.isnull(), yticklabels=False, cbar=False, cmap='viridis')
df2.isna().sum()
# Out:
# Title                  0
# IMDb ID                0
# Release Year           5
# Genre                  0
# Cast                 579
# Synopsis               0
# Rating                 0
# Runtime             9748
# Certificate        40920
# Number of Votes        0
# Gross Revenue      82035
# dtype: int64

# %%
df2
# Out:
#                                     Title     IMDb ID   Release Year  \
# 0     Spider-Man: Across the Spider-Verse   tt9362722           2023
# 1                                   FUBAR  tt13064902         2023–
# 2                                   Barry   tt5348176      2018–2023
# 3                    John Wick: Chapter 4  tt10366206           2023
# 4                                  Fast X   tt5433140           2023
# ...                                   ...         ...            ...
# 7193                   The Unknown Ranger   tt0028448           1936
# 7194                       Pioneer Trails   tt0014359           1923
# 7195                Riderà! (Cuore matto)   tt0062199           1967
# 7196                    Earth Without War   tt6065900           2017
# 7197                          TSTG Teaser   tt6653060  2017 TV Movie
#
#                              Genre  \
# 0     Animation, Action, Adventure
# 1      Action, Adventure, Thriller
# ...
